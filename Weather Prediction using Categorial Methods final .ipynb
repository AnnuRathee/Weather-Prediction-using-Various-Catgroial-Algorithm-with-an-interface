# %% [markdown]
# # Libraries

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Reading the dataset 
df = pd.read_csv('weather_classification_data.csv')
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %% [markdown]
# # Gathering the Basic Information

# %%
#Shape of the Dataset i.e number of rows and columns
shape = df.shape
print("Shape = ",shape)
# Out:
# Shape =  (13200, 11)

# %%
#Information of each column
print("-Information of each column-")
info = df.info()
print(info)
# Out:
# -Information of each column-
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13200 entries, 0 to 13199
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Temperature           13200 non-null  float64
#  1   Humidity              13200 non-null  int64
#  2   Wind Speed            13200 non-null  float64
#  3   Precipitation (%)     13200 non-null  float64
#  4   Cloud Cover           13200 non-null  object
#  5   Atmospheric Pressure  13200 non-null  float64
#  6   UV Index              13200 non-null  int64
#  7   Season                13200 non-null  object
#  8   Visibility (km)       13200 non-null  float64
#  9   Location              13200 non-null  object
#  10  Weather Type          13200 non-null  object
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.1+ MB
# None

# %%
#Count of the rows in each column
print("-Count of the rows in each column-")
count = df.count()
print(count)
# Out:
# -Count of the rows in each column-
# Temperature             13200
# Humidity                13200
# Wind Speed              13200
# Precipitation (%)       13200
# Cloud Cover             13200
# Atmospheric Pressure    13200
# UV Index                13200
# Season                  13200
# Visibility (km)         13200
# Location                13200
# Weather Type            13200
# dtype: int64

# %%
#Minimum value from each column
print("-Minimum value from each column-")
min = df.min()
print(min)
# Out:
# -Minimum value from each column-
# Temperature               -25.0
# Humidity                     20
# Wind Speed                  0.0
# Precipitation (%)           0.0
# Cloud Cover               clear
# Atmospheric Pressure     800.12
# UV Index                      0
# Season                   Autumn
# Visibility (km)             0.0
# Location                coastal
# Weather Type             Cloudy
# dtype: object

# %%
#Maximum value from each column
print("  -Maximum value from each column-  ")
max = df.max()
print(max)
# Out:
#   -Maximum value from each column-
# Temperature                     109.0
# Humidity                          109
# Wind Speed                       48.5
# Precipitation (%)               109.0
# Cloud Cover             partly cloudy
# Atmospheric Pressure          1199.21
# UV Index                           14
# Season                         Winter
# Visibility (km)                  20.0
# Location                     mountain
# Weather Type                    Sunny
# dtype: object

# %%
#Measure of Central Tendency and Five point summary
print("-Measure of Central Tendency and Five Point Summary-")
df.describe()
# Out:
# -Measure of Central Tendency and Five Point Summary-
#         Temperature      Humidity    Wind Speed  Precipitation (%)  \
# count  13200.000000  13200.000000  13200.000000       13200.000000
# mean      19.127576     68.710833      9.832197          53.644394
# std       17.386327     20.194248      6.908704          31.946541
# min      -25.000000     20.000000      0.000000           0.000000
# 25%        4.000000     57.000000      5.000000          19.000000
# 50%       21.000000     70.000000      9.000000          58.000000
# 75%       31.000000     84.000000     13.500000          82.000000
# max      109.000000    109.000000     48.500000         109.000000
#
#        Atmospheric Pressure      UV Index  Visibility (km)
# count          13200.000000  13200.000000     13200.000000
# mean            1005.827896      4.005758         5.462917
# std               37.199589      3.856600         3.371499
# min              800.120000      0.000000         0.000000
# ...

# %%
#Top 5 rows of dataset
print("Top 5 rows of dataset")
df.head()
# Out:
# Top 5 rows of dataset
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0        73         9.5               82.0  partly cloudy
# 1         39.0        96         8.5               71.0  partly cloudy
# 2         30.0        64         7.0               16.0          clear
# 3         38.0        83         1.5               82.0          clear
# 4         27.0        74        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2  Winter              3.5    inland
# 1               1011.43         7  Spring             10.0    inland
# 2               1018.72         5  Spring              5.5  mountain
# 3               1026.25         7  Spring              1.0   coastal
# 4                990.67         1  Winter              2.5  mountain
#
#   Weather Type
# 0        Rainy
# 1       Cloudy
# 2        Sunny
# 3        Sunny
# 4        Rainy

# %%
#Bottom 5 rows of dataset
print("Bottom 5 rows of dataset")
df.tail()
# Out:
# Bottom 5 rows of dataset
#        Temperature  Humidity  Wind Speed  Precipitation (%) Cloud Cover  \
# 13195         10.0        74        14.5               71.0    overcast
# 13196         -1.0        76         3.5               23.0      cloudy
# 13197         30.0        77         5.5               28.0    overcast
# 13198          3.0        76        10.0               94.0    overcast
# 13199         -5.0        38         0.0               92.0    overcast
#
#        Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 13195               1003.15         1  Summer              1.0  mountain
# 13196               1067.23         1  Winter              6.0   coastal
# 13197               1012.69         3  Autumn              9.0   coastal
# 13198                984.27         0  Winter              2.0    inland
# 13199               1015.37         5  Autumn             10.0  mountain
#
#       Weather Type
# 13195        Rainy
# 13196        Snowy
# ...

# %%
#Check the null values
print("Null Values")
df.isnull().sum()
# Out:
# Null Values
# Temperature             0
# Humidity                0
# Wind Speed              0
# Precipitation (%)       0
# Cloud Cover             0
# Atmospheric Pressure    0
# UV Index                0
# Season                  0
# Visibility (km)         0
# Location                0
# Weather Type            0
# dtype: int64

# %%
#Check the Duplicate values
print("Duplicate Values")
df.duplicated().sum()
# Out:
# Duplicate Values
# 0

# %%
#Drop the Unnecessary Columns
df.drop(columns = ['Cloud Cover','Season','Location'],inplace = True)
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 0             14.0        73         9.5               82.0
# 1             39.0        96         8.5               71.0
# 2             30.0        64         7.0               16.0
# 3             38.0        83         1.5               82.0
# 4             27.0        74        17.0               66.0
# ...            ...       ...         ...                ...
# 13195         10.0        74        14.5               71.0
# 13196         -1.0        76         3.5               23.0
# 13197         30.0        77         5.5               28.0
# 13198          3.0        76        10.0               94.0
# 13199         -5.0        38         0.0               92.0
#
#        Atmospheric Pressure  UV Index  Visibility (km) Weather Type
# 0                   1010.82         2              3.5        Rainy
# 1                   1011.43         7             10.0       Cloudy
# ...

# %%
#List of unique values from weather Type
df['Weather Type'].unique()
# Out:
# array(['Rainy', 'Cloudy', 'Sunny', 'Snowy'], dtype=object)

# %%
df['Weather Type']=df['Weather Type'].map({'Rainy':0, 'Cloudy':1,'Sunny':2,'Snowy':3})
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 0             14.0        73         9.5               82.0
# 1             39.0        96         8.5               71.0
# 2             30.0        64         7.0               16.0
# 3             38.0        83         1.5               82.0
# 4             27.0        74        17.0               66.0
# ...            ...       ...         ...                ...
# 13195         10.0        74        14.5               71.0
# 13196         -1.0        76         3.5               23.0
# 13197         30.0        77         5.5               28.0
# 13198          3.0        76        10.0               94.0
# 13199         -5.0        38         0.0               92.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)  Weather Type
# 0                   1010.82         2              3.5             0
# 1                   1011.43         7             10.0             1
# ...

# %% [markdown]
# # Identification of outliers using boxplot and IQR

# %%
#Box Plot for each Column
box = sns.boxplot(df)
box.set_title('BoxPlot for each column')
plt.show()

# %%
#Box plot for each column 
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

sns.boxplot(data=df, x='Temperature', palette = 'Blues',ax=axes[0, 0])
axes[0, 0].set_title('Box Plot for Temperature')

sns.boxplot(data=df, x='Humidity',palette ='husl', ax=axes[0, 1])
axes[0, 1].set_title('Box Plot for Humidity')

sns.boxplot(data=df, x='Visibility (km)',palette ='deep', ax=axes[1, 0])
axes[1, 0].set_title('Box Plot for Visibility (km)')

sns.boxplot(data=df, x='Precipitation (%)',palette ='viridis', ax=axes[1, 1])
axes[1, 1].set_title('Box Plot for Precipitation')

plt.tight_layout()
plt.show()

# %%
#Box plot for each column
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

sns.boxplot(data=df, x='Atmospheric Pressure', palette = 'Blues',ax=axes[0, 0])
axes[0, 0].set_title('Box Plot for Atmospheric Pressure')

sns.boxplot(data=df, x='UV Index',palette ='husl', ax=axes[0, 1])
axes[0, 1].set_title('Box Plot for UV Index')

sns.boxplot(data=df, x='Wind Speed',palette ='deep', ax=axes[1, 0])
axes[1, 0].set_title('Box Plot for Wind Speed')

sns.boxplot(data=df, x='Weather Type',palette ='viridis', ax=axes[1, 1])
axes[1, 1].set_title('Box Plot for Weather Type')


plt.tight_layout()
plt.show()

# %%
# Check out the outliers in the temperature column
Q1 = df['Temperature'].quantile(0.25)
Q3 = df['Temperature'].quantile(0.75)
IQR = Q3-Q1
threshold=1.5 
admit_outliers=df[(df['Temperature'] <Q1-threshold*IQR) | (df['Temperature'] > Q3+ threshold*IQR)]
admit_outliers
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 210           78.0        81         8.0               78.0
# 228           73.0        82        47.0              107.0
# 535           80.0        76         3.0               93.0
# 709           74.0       101        18.0               76.0
# 730           76.0        91        13.5               82.0
# ...            ...       ...         ...                ...
# 12752         90.0        83        15.0               98.0
# 12814         72.0        88        12.0               83.0
# 12878         95.0        96         1.0               84.0
# 13065         97.0        95         7.5               79.0
# 13108         81.0        81        10.5               96.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)  Weather Type
# 210                 1010.19         1              4.5             1
# 228                 1002.73         0              0.5             0
# ...

# %%
df=df.drop(admit_outliers.index)
sns.boxplot(x='Temperature',data=df)
# Out:
# <Axes: xlabel='Temperature'>

# %%
# Check out the outliers in the Humidity column
Q1 = df['Humidity'].quantile(0.25)
Q3 = df['Humidity'].quantile(0.75)
IQR = Q3-Q1
threshold=1.5 
admit_outliers=df[(df['Humidity'] <Q1-threshold*IQR) | (df['Humidity'] > Q3+ threshold*IQR)]
admit_outliers
# Out:
# Empty DataFrame
# Columns: [Temperature, Humidity, Wind Speed, Precipitation (%), Atmospheric Pressure, UV Index, Visibility (km), Weather Type]
# Index: []

# %%
# Check out the outliers in the Atmospheric Pressure column
Q1 = df['Atmospheric Pressure'].quantile(0.25)
Q3 = df['Atmospheric Pressure'].quantile(0.75)
IQR = Q3-Q1
threshold=1.5 
admit_outliers=df[(df['Atmospheric Pressure'] <Q1-threshold*IQR) | (df['Atmospheric Pressure'] > Q3+ threshold*IQR)]
admit_outliers
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 10            35.0        45         6.0               86.0
# 38            -9.0        49         1.5               58.0
# 58            31.0        70         0.5               69.0
# 72            11.0        52         6.0               97.0
# 85            32.0        35         2.5               63.0
# ...            ...       ...         ...                ...
# 13167         33.0        73         5.0               31.0
# 13168         44.0        45         7.0               28.0
# 13178          0.0        50        11.5               82.0
# 13184          3.0        62         7.5               14.0
# 13196         -1.0        76         3.5               23.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)  Weather Type
# 10                   879.88         2              1.0             1
# 38                  1132.20         8             16.5             3
# ...

# %%
#Drop all the outliers present in the AAtmospheric Pressure column
df=df.drop(admit_outliers.index)
sns.boxplot(x='Atmospheric Pressure',data=df)
# Out:
# <Axes: xlabel='Atmospheric Pressure'>

# %%
# Check out the outliers in the Wind Speed column
Q1 = df['Wind Speed'].quantile(0.25)
Q3 = df['Wind Speed'].quantile(0.75)
IQR = Q3-Q1
threshold=1.5 
admit_outliers=df[(df['Wind Speed'] <Q1-threshold*IQR) | (df['Wind Speed'] > Q3+ threshold*IQR)]
admit_outliers
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 63             3.0        75        46.5               87.0
# 90            15.0        81        28.5               71.0
# 123           -3.0        92        28.0               99.0
# 208           34.0        99        34.0               74.0
# 237            8.0        78        34.5              106.0
# ...            ...       ...         ...                ...
# 12979          3.0       106        45.0               94.0
# 12999         -2.0        90        28.5               84.0
# 13066          5.0       102        31.0              108.0
# 13113         42.0       106        32.5              103.0
# 13176         19.0       100        36.0               86.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)  Weather Type
# 63                   996.85         5              4.5             3
# 90                  1008.00         4              6.0             1
# ...

# %%
df=df.drop(admit_outliers.index)
sns.boxplot(x='Wind Speed',data=df)
# Out:
# <Axes: xlabel='Wind Speed'>

# %%
# Check out the outliers in the UV Index column
Q1 = df['UV Index'].quantile(0.25)
Q3 = df['UV Index'].quantile(0.75)
IQR = Q3-Q1
threshold=1.5 
admit_outliers=df[(df['UV Index'] <Q1-threshold*IQR) | (df['UV Index'] > Q3+ threshold*IQR)]
admit_outliers
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 221           63.0        86        13.0               75.0
# 556           15.0        99        13.5               80.0
# 663           12.0        24        10.0               12.0
# 860            9.0        73        10.0               84.0
# 877           -1.0        56         5.0               70.0
# ...            ...       ...         ...                ...
# 12848         11.0        74        10.0               70.0
# 12871         20.0        38         4.5               17.0
# 12877         40.0        41         5.5               52.0
# 12991         17.0        95         6.5              107.0
# 13185         37.0       106        23.5              104.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)  Weather Type
# 221                 1027.31        14              2.5             2
# 556                 1002.93        14              9.0             1
# ...

# %%
df=df.drop(admit_outliers.index)
sns.boxplot(x='UV Index',data=df)
# Out:
# <Axes: xlabel='UV Index'>

# %%
# Check out the outliers in the Visibility (km) column
Q1 = df['Visibility (km)'].quantile(0.25)
Q3 = df['Visibility (km)'].quantile(0.75)
IQR = Q3-Q1
threshold=1.5 
admit_outliers=df[(df['Visibility (km)'] <Q1-threshold*IQR) | (df['Visibility (km)'] > Q3+ threshold*IQR)]
admit_outliers
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)  \
# 511           33.0        69         5.0               81.0
# 822           34.0        20         4.5               36.0
# 931          -19.0        59         4.0               11.0
# 945           25.0        32         8.5               82.0
# 949           43.0        30         4.0               97.0
# ...            ...       ...         ...                ...
# 12570         15.0        68         3.5               57.0
# 12606          4.0        70         5.0               50.0
# 12776         25.0        75         2.5               72.0
# 13018         -9.0        32         5.0               21.0
# 13025         66.0       100         7.0              109.0
#
#        Atmospheric Pressure  UV Index  Visibility (km)  Weather Type
# 511                  994.68        12             16.5             3
# 822                  966.37         6             16.0             0
# ...

# %%
df=df.drop(admit_outliers.index)
sns.boxplot(x='Visibility (km)',data=df)
# Out:
# <Axes: xlabel='Visibility (km)'>

# %% [markdown]
# # Dataset Trend Visualization

# %%
# Line plot for Temperature vs Humidity and Precepitation vs Wind Speed

fig, axes = plt.subplots(1, 2, figsize=(12, 4))

sns.lineplot(data=df, x='Temperature' ,y='Humidity',color ='g',ax=axes[0])
axes[0].set_title('Line Plot for Temperature vs Humidity')

sns.lineplot(data=df, x='Precipitation (%)',y='Wind Speed', ax=axes[1])
axes[1].set_title('Line Plot for Precipitation vs Wind Speed')

plt.tight_layout()
plt.show()

# %%
# Line plot for Temperature vs Atmospheric Pressure and Visibility (Km) vs Wind Speed
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

sns.lineplot(data=df, x='Temperature' ,y='Atmospheric Pressure',color ='g',ax=axes[0])
axes[0].set_title('Line Plot for Temperature vs Atmospheric Pressure')

sns.lineplot(data=df, x='Visibility (km)',y='Wind Speed', ax=axes[1])
axes[1].set_title('Line Plot for Visibility vs Wind Speed')

plt.tight_layout()
plt.show()

# %%
#Histogram for all the columns
df.hist(figsize = (15,8))
# Out:
# array([[<Axes: title={'center': 'Temperature'}>,
#         <Axes: title={'center': 'Humidity'}>,
#         <Axes: title={'center': 'Wind Speed'}>],
#        [<Axes: title={'center': 'Precipitation (%)'}>,
#         <Axes: title={'center': 'Atmospheric Pressure'}>,
#         <Axes: title={'center': 'UV Index'}>],
#        [<Axes: title={'center': 'Visibility (km)'}>,
#         <Axes: title={'center': 'Weather Type'}>, <Axes: >]], dtype=object)

# %%
#Pie Chart for all the columns
v = df['Weather Type'].value_counts().values
labels = ['Rainy', 'Cloudy', 'sunny', 'snowy']
explode = [0.2,0,0,0]
#pie chart
import matplotlib.pyplot as plt
plt.figure(figsize = (6,6))
plt.pie(x=v,labels=labels,explode=explode,autopct = '%0.1f%%')
plt.show()

# %%
#Pairplot for entire data
sns.pairplot(df)
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#Heatmap for Correlation Data 
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Test and Train Splitting

# %%
# splitting the data into x and y
x = df[['Temperature', 'Humidity', 'Wind Speed']]  # Features
y = df['Weather Type']  # Target variable (e.g., sunny, rainy, cloudy)
x
# Out:
#        Temperature  Humidity  Wind Speed
# 0             14.0        73         9.5
# 1             39.0        96         8.5
# 2             30.0        64         7.0
# 3             38.0        83         1.5
# 4             27.0        74        17.0
# ...            ...       ...         ...
# 13194         29.0        62        13.0
# 13195         10.0        74        14.5
# 13197         30.0        77         5.5
# 13198          3.0        76        10.0
# 13199         -5.0        38         0.0
#
# [11652 rows x 3 columns]

# %%
y
# Out:
# 0        0
# 1        1
# 2        2
# 3        2
# 4        0
#         ..
# 13194    1
# 13195    0
# 13197    1
# 13198    3
# 13199    0
# Name: Weather Type, Length: 11652, dtype: int64

# %%
# Splitting the x and y into train and test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)
x_train
# Out:
#        Temperature  Humidity  Wind Speed
# 10642         21.0        69         0.0
# 3565          -2.0        96        14.0
# 1382          42.0        58         6.0
# 5886          -9.0        70        13.5
# 8463          32.0        82        12.0
# ...            ...       ...         ...
# 12774         33.0        75         4.0
# 5816           2.0        72         2.5
# 6040          64.0        85        14.0
# 968           28.0        56         4.5
# 8189          -2.0        93         6.5
#
# [6991 rows x 3 columns]

# %%
#Transforming the data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler() #removes the mean and scales each feature/variable to unit variance.
x_train = scaler.fit_transform(x_train) 
x_test = scaler.transform(x_test)
x_test
# Out:
# array([[-0.58792833, -0.37800751, -0.57622638],
#        [ 0.48538112,  1.35474438,  0.38737961],
#        [-0.20911323,  0.23355198, -0.75142747],
#        ...,
#        [-0.08284153, -0.32704422, -0.57622638],
#        [-0.20911323,  1.45667096,  0.91298287],
#        [-1.53496608,  0.23355198,  0.03697743]])

# %% [markdown]
# # Logistic Regressor

# %%
#Importing the LogesticRegression library
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
# Assigning the Parameters
from sklearn.model_selection import GridSearchCV
parameter ={'penalty':['l1','l2','elasticnet'],
             'C':[1,2,3,4,5,6,10,20,30,40,50],
              'max_iter':[100,200,300]}

classifier_regressor = GridSearchCV(classifier,
                                    param_grid = parameter,
                                    scoring='accuracy',
                                    cv = 5)

classifier_regressor.fit(x_train, y_train)
print(classifier_regressor.best_score_)
# Out:
# 0.7798581860535985
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 330 fits failed out of a total of 495.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 165 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py", line 1151, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
#Predicting x_test
classifier_regressor.predict(x_test)
# Out:
# array([1, 0, 1, ..., 1, 0, 3], dtype=int64)

# %%
# assigning the y_pred 
y_pred = classifier_regressor.predict(x_test)
y_pred
# Out:
# array([1, 0, 1, ..., 1, 0, 3], dtype=int64)

# %%
# Calculating the accuracy
from sklearn.metrics import accuracy_score,classification_report
score_lr = accuracy_score(y_pred,y_test)
print("Accuracy:",score_lr*100,"%")
# Out:
# Accuracy: 77.66573696631625 %

# %%
#Predicting the result
lr = classifier_regressor.predict([[35.0,45,6.0]]) 
lr
# Out:
# array([0], dtype=int64)

# %%
#Predicting the result2
lr2 = classifier_regressor.predict([[63,86,13]]) 
lr2
# Out:
# array([0], dtype=int64)

# %%
#Predicting the result3
lr3 = classifier_regressor.predict([[37,106,23.5]]) 
lr3
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Decision Tree

# %%
# importing the Decision Tree Classifer model
from sklearn.tree import DecisionTreeClassifier
treemodel = DecisionTreeClassifier(max_depth = 2)
print("TreeModel = ",treemodel)
#Fitting the x_train and y_train into the model
treemodel.fit(x_train, y_train)
# Out:
# TreeModel =  DecisionTreeClassifier(max_depth=2)
# DecisionTreeClassifier(max_depth=2)

# %%
#Plotting the chart for treemodel with max depth as 2
import  matplotlib.pyplot as plt
from sklearn import tree

plt.figure(figsize = (15,10))

tree.plot_tree(treemodel,filled = True)
# Out:
# [Text(0.5, 0.8333333333333334, 'x[0] <= -0.809\ngini = 0.75\nsamples = 6991\nvalue = [1732, 1785, 1776, 1698]'),
#  Text(0.25, 0.5, 'x[1] <= -0.556\ngini = 0.029\nsamples = 1702\nvalue = [8, 11, 6, 1677]'),
#  Text(0.125, 0.16666666666666666, 'gini = 0.707\nsamples = 23\nvalue = [7, 9, 4, 3]'),
#  Text(0.375, 0.16666666666666666, 'gini = 0.006\nsamples = 1679\nvalue = [1, 2, 2, 1674]'),
#  Text(0.75, 0.5, 'x[1] <= -1.015\ngini = 0.669\nsamples = 5289\nvalue = [1724, 1774, 1770, 21]'),
#  Text(0.625, 0.16666666666666666, 'gini = 0.049\nsamples = 973\nvalue = [5, 9, 949, 10]'),
#  Text(0.875, 0.16666666666666666, 'gini = 0.638\nsamples = 4316\nvalue = [1719, 1765, 821, 11]')]

# %%
#Predicting the x_test and asssigning it to 
treemodel.predict(x_test)
y_pred = treemodel.predict(x_test)

# %%
#Calculating the accuracy
from sklearn.metrics import accuracy_score,classification_report
score = accuracy_score(y_pred,y_test)
print("Accuracy:",score)
# Out:
# Accuracy: 0.634627762282772

# %%
# Display the classification report
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.99      0.41      0.58      2864
#            2       0.52      0.97      0.67       619
#            3       0.98      0.99      0.99      1178
#
#     accuracy                           0.63      4661
#    macro avg       0.62      0.59      0.56      4661
# weighted avg       0.93      0.63      0.70      4661
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
# Again assigning the model without any max depth
treemodel = DecisionTreeClassifier()
print("TreeModel = ",treemodel)
treemodel.fit(x_train, y_train)
# Out:
# TreeModel =  DecisionTreeClassifier()
# DecisionTreeClassifier()

# %%
# Graph for the model with the actual depth
import  matplotlib.pyplot as plt
from sklearn import tree
plt.figure(figsize = (15,10))
tree.plot_tree(treemodel,filled = True)
# Out:
# [Text(0.21031155288673065, 0.9833333333333333, 'x[0] <= -0.809\ngini = 0.75\nsamples = 6991\nvalue = [1732, 1785, 1776, 1698]'),
#  Text(0.0118184260005372, 0.95, 'x[1] <= -0.556\ngini = 0.029\nsamples = 1702\nvalue = [8, 11, 6, 1677]'),
#  Text(0.0041185423941266005, 0.9166666666666666, 'x[1] <= -1.881\ngini = 0.707\nsamples = 23\nvalue = [7, 9, 4, 3]'),
#  Text(0.0014325364849136, 0.8833333333333333, 'x[1] <= -2.366\ngini = 0.375\nsamples = 8\nvalue = [0, 6, 2, 0]'),
#  Text(0.0007162682424568, 0.85, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.0021488047273704003, 0.85, 'x[1] <= -2.238\ngini = 0.48\nsamples = 5\nvalue = [0, 3, 2, 0]'),
#  Text(0.0014325364849136, 0.8166666666666667, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0]'),
#  Text(0.0028650729698272, 0.8166666666666667, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0]'),
#  Text(0.0068045483033396005, 0.8833333333333333, 'x[0] <= -1.44\ngini = 0.684\nsamples = 15\nvalue = [7, 3, 2, 3]'),
# ...

# %%
treemodel.predict(x_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 3], dtype=int64)

# %%
# Predicting the x test value into y_pred
y_pred = treemodel.predict(x_test)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 3], dtype=int64)

# %%
# Calculatin the accuracy
score_dt = accuracy_score(y_pred,y_test)
print("Accuracy:",score_dt*100,"%")
# Out:
# Accuracy: 77.98755631838661 %

# %%
#Predicting the result
dt = treemodel.predict([[35.0,45,6.0]]) 
dt
# Out:
# array([1], dtype=int64)

# %%
#Predicting the result2
dt2 = treemodel.predict([[63,86,13]]) 
dt2
# Out:
# array([1], dtype=int64)

# %%
#Predicting the result3
dt3 = treemodel.predict([[37,106,23.5]]) 
dt3
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # Random Forest

# %%
# Importing all th important libraries for random forest
from sklearn.metrics import roc_curve,auc
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
import time
fit_rf = RandomForestClassifier(random_state = 40)

# %%
# hyperparameter optimization for a Random Forest model using GridSearchCV.
np.random.seed(40)
start=time.time()
param_dist={'max_depth':[2,3,4,5],
           'bootstrap':[True,False],
           'max_features':['auto','sqrt','log2',None],
           'criterion':['gini','entropy']}
cv_rf=GridSearchCV(fit_rf,cv=10,param_grid=param_dist,n_jobs=3)

cv_rf.fit(x_train,y_train)
print('best parameters using Grid Search: \n',cv_rf.best_params_)
end=time.time()
print('time taken in grid search: %0.2f'%(end-start) )
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 160 fits failed out of a total of 640.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 732, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py", line 1144, in wrapper
#     estimator._validate_params()
#   File "C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py", line 637, in _validate_params
#     validate_parameter_constraints(
# ...

# %%
fit_rf.set_params(criterion='entropy',max_features='log2',max_depth=5)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, max_features='log2',
#                        random_state=40)

# %%
# Fitting the model
fit_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, max_features='log2',
#                        random_state=40)

# %%
#Prediction
prediction_rf=fit_rf.predict(x_test)
print(prediction_rf)
# Out:
# [1 0 1 ... 1 0 3]

# %%
#Calculating the accuracy
score_rf=fit_rf.score(x_test,y_test)
print("Accuracy:",score_rf*100,"%")
# Out:
# Accuracy: 80.58356575842095 %

# %%
#Predict the result
rf = fit_rf.predict([[35.0,45,6.0]]) 
rf
# Out:
# array([1], dtype=int64)

# %%
#Predict the result2
rf2 = fit_rf.predict([[63,86,13]]) 
rf2
# Out:
# array([1], dtype=int64)

# %%
#Predict the result3
rf3 = fit_rf.predict([[37,106,23.5]]) 
rf3
# Out:
# array([1], dtype=int64)

# %% [markdown]
# # K - Nearest Neighbour

# %%
# Importing the KNN library 
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)

# %%
#Fitting of the model
knn.fit(x_train, y_train)
y_prediction = knn.predict(x_test)

# %%
#Creating a confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_prediction)
# Out:
# array([[ 828,  246,   29,    2],
#        [ 266,  788,  134,    8],
#        [  83,  194,  884,    4],
#        [   6,    6,    9, 1174]], dtype=int64)

# %%
#calculating the accuracy
from sklearn.metrics import accuracy_score
score_knn = accuracy_score(y_true=y_test,y_pred = y_prediction,normalize = True)
print("Accuracy:",score_knn*100,"%")
# Out:
# Accuracy: 78.82428663376957 %

# %%
# Prediction of the result
knnp = knn.predict([[35.0,45,6.0]]) 
knnp
# Out:
# array([0], dtype=int64)

# %%
# Prediction of the result2
knnp2 = knn.predict([[63,86,13]]) 
knnp2
# Out:
# array([0], dtype=int64)

# %%
# Prediction of the result3
knnp3 = knn.predict([[37,106,23.5]]) 
knnp3
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Gaussian Naive Bayes

# %%
# Importing the Gaussian Naive Bayes 
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()

# %%
#Fitting of the model
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
#Prediction
pred = model.predict(x_test)
print(pred[:150])
# Out:
# [1 0 1 2 1 2 0 3 1 3 3 2 2 3 0 0 2 2 0 2 1 3 0 0 0 1 1 0 0 3 1 1 2 3 3 3 2
#  3 1 0 1 1 2 2 2 2 1 3 2 2 0 2 2 3 1 1 1 0 1 2 3 1 0 2 1 1 3 3 1 1 0 0 3 3
#  3 2 0 1 0 0 2 3 1 2 1 0 3 0 0 0 3 2 0 1 3 3 2 1 2 1 2 3 1 2 2 2 1 2 1 0 1
#  2 3 3 2 2 2 2 0 2 0 3 0 2 1 3 0 3 3 1 3 3 3 1 3 3 0 3 3 1 0 2 0 1 3 1 2 0
#  2 1]

# %%
# Construction of heatmap for confusion matrix between truth and predicted values
mat = confusion_matrix(pred,y_test)
names = np.unique(pred)
sns.heatmap(mat,square=True,annot=True,fmt='d',cbar = False)
plt.xlabel('Truth')
plt.ylabel('Predicted')
plt.plot()
# Out:
# []

# %%
#Calculating the accuracy
score_gnb = accuracy_score(pred,y_test)
print("Accuracy:",score_gnb*100,"%")
# Out:
# Accuracy: 78.28792104698562 %

# %%
#Predicting the result
gnb = model.predict([[35.0,45,6.0]]) 
gnb
# Out:
# array([2], dtype=int64)

# %%
#Predicting the result2
gnb2 = model.predict([[63,86,13]]) 
gnb2
# Out:
# array([2], dtype=int64)

# %%
#Predicting the result3
gnb3 = model.predict([[37,106,23.5]]) 
gnb3
# Out:
# array([2], dtype=int64)

# %% [markdown]
# # Support Vector Machine (SVM)

# %%
# Import the SVM algo 
from sklearn.svm import SVC
clf = SVC(kernel='linear')
# Fit into the model
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)

# %%
#Calculate the accuracy
score_svm = accuracy_score(y_test,y_pred)
print("Accuracy:",score_svm*100,"%")
# Out:
# Accuracy: 77.88028320102983 %

# %%
#Predict the result
svm = clf.predict([[35.0,45,6.0]]) 
svm
# Out:
# array([0], dtype=int64)

# %%
#Predict the result 2
svm2 = clf.predict([[63,86,13]]) 
svm2
# Out:
# array([0], dtype=int64)

# %%
#Predict the result 3
svm3 = clf.predict([[37,106,23.5]]) 
svm3
# Out:
# array([0], dtype=int64)

# %% [markdown]
# # Accuracy Comparison

# %%
#Accuracy Comparison
data = {
    'Model_Name': ['Logistic Regression', 'Decision Tree', 'Random Forest', 'KNN','GuassianNB','SVM'],
    'Accuracy': [score_lr,score_dt,score_rf,score_knn,score_gnb,score_svm]
}
print("Comparison Table for all the Categorials Approaches")
comparison = pd.DataFrame(data)
comparison
# Out:
# Comparison Table for all the Categorials Approaches
#             Model_Name  Accuracy
# 0  Logistic Regression  0.776657
# 1        Decision Tree  0.779876
# 2        Random Forest  0.805836
# 3                  KNN  0.788243
# 4           GuassianNB  0.782879
# 5                  SVM  0.778803

# %%
#Sorting all the algorithms by their accuracy
comparison.sort_values(by='Accuracy', ascending=False)
# Out:
#             Model_Name  Accuracy
# 2        Random Forest  0.805836
# 3                  KNN  0.788243
# 4           GuassianNB  0.782879
# 1        Decision Tree  0.779876
# 5                  SVM  0.778803
# 0  Logistic Regression  0.776657

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


data = pd.DataFrame({
    'Model_Name': ['Logistic Regression', 'Decision Tree', 'Random Forest', 'KNN', 'GaussianNB', 'SVM'],
    'Accuracy': [score_lr*100, score_dt*100, score_rf*100, score_knn*100, score_gnb*100, score_svm*100]
})

# Set the figure size
plt.figure(figsize=(8, 8))

# Create the bar plot
ax = sns.barplot(x='Model_Name', y='Accuracy', data=data)

# Add labels to each bar
for p in ax.patches:
    ax.annotate(format(p.get_height(), '.2f'), 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center',
                xytext=(0, 9), 
                textcoords='offset points')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45, ha='right')
plt.title('Accuracy vs Algorithms Bar chart')

# Display the plot
plt.show()

# %% [markdown]
# # Prediction Table

# %%
#Prediction table
data = {
    'Model_Name': ['Logistic Regression', 'Decision Tree', 'Random Forest', 'KNN','GuassianNB','SVM'],
    'Accuracy': [score_lr,score_dt,score_rf,score_knn,score_gnb,score_svm],
    'x_values': [[35.0,45,6.0],[35.0,45,6.0],[35.0,45,6.0],[35.0,45,6.0],[35.0,45,6.0],[35.0,45,6.0]],
    'Prediction1': [lr,dt,rf,knnp,gnb,svm],
    'x_values2': [[63,86,13],[63,86,13],[63,86,13],[63,86,13],[63,86,13],[63,86,13]],
    'Prediction2': [lr2,dt2,rf2,knnp2,gnb2,svm2],
    'x_values3': [[37,106,23.5],[37,106,23.5],[37,106,23.5],[37,106,23.5],[37,106,23.5],[37,106,23.5]],
    'Prediction3': [lr3,dt3,rf3,knnp3,gnb3,svm3]
    
}
print("Prediction Table for all the Categorials Approaches")
comparison = pd.DataFrame(data)
comparison
# Out:
# Prediction Table for all the Categorials Approaches
#             Model_Name  Accuracy         x_values Prediction1     x_values2  \
# 0  Logistic Regression  0.776657  [35.0, 45, 6.0]         [0]  [63, 86, 13]
# 1        Decision Tree  0.779876  [35.0, 45, 6.0]         [1]  [63, 86, 13]
# 2        Random Forest  0.805836  [35.0, 45, 6.0]         [1]  [63, 86, 13]
# 3                  KNN  0.788243  [35.0, 45, 6.0]         [0]  [63, 86, 13]
# 4           GuassianNB  0.782879  [35.0, 45, 6.0]         [2]  [63, 86, 13]
# 5                  SVM  0.778803  [35.0, 45, 6.0]         [0]  [63, 86, 13]
#
#   Prediction2        x_values3 Prediction3
# 0         [0]  [37, 106, 23.5]         [0]
# 1         [1]  [37, 106, 23.5]         [1]
# 2         [1]  [37, 106, 23.5]         [1]
# 3         [0]  [37, 106, 23.5]         [0]
# 4         [2]  [37, 106, 23.5]         [2]
# 5         [0]  [37, 106, 23.5]         [0]

# %%
comparison.sort_values(by='Accuracy', ascending=False)
# Out:
#             Model_Name  Accuracy         x_values Prediction1     x_values2  \
# 2        Random Forest  0.805836  [35.0, 45, 6.0]         [1]  [63, 86, 13]
# 3                  KNN  0.788243  [35.0, 45, 6.0]         [0]  [63, 86, 13]
# 4           GuassianNB  0.782879  [35.0, 45, 6.0]         [2]  [63, 86, 13]
# 1        Decision Tree  0.779876  [35.0, 45, 6.0]         [1]  [63, 86, 13]
# 5                  SVM  0.778803  [35.0, 45, 6.0]         [0]  [63, 86, 13]
# 0  Logistic Regression  0.776657  [35.0, 45, 6.0]         [0]  [63, 86, 13]
#
#   Prediction2        x_values3 Prediction3
# 2         [1]  [37, 106, 23.5]         [1]
# 3         [0]  [37, 106, 23.5]         [0]
# 4         [2]  [37, 106, 23.5]         [2]
# 1         [1]  [37, 106, 23.5]         [1]
# 5         [0]  [37, 106, 23.5]         [0]
# 0         [0]  [37, 106, 23.5]         [0]
